# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\Movie-Rating.csv")

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
df.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                     Film   Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer   Comedy                         87
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.columns=['Film','Genre','Criticrating','AudiunceRating','BudgetMillions','Year']

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Criticrating', 'AudiunceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Criticrating  AudiunceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   AudiunceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.Film=df.Film.astype('category')

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   AudiunceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
df.describe()
# Out:
#        Criticrating  AudiunceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
from matplotlib import pyplot as plt  # Import pyplot from matplotlib
import seaborn as sns  # Import seaborn for statistical graphics
# %matplotlib inline  # Display plots inline in Jupyter Notebook
import warnings  # Import warnings module to handle warnings
warnings.filterwarnings('ignore')  # Suppress warnings during execution
# Out:
# UsageError: unrecognized arguments: # Display plots inline in Jupyter Notebook

# %%
j = sns.jointplot(data=df, x='CriticRating', y='AudienceRating', kind='reg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 j = sns.jointplot(data=df, x='CriticRating', y='AudienceRating', kind='reg')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
#    2250 if grid.hue is not None:
#    2251     marginal_kws.setdefault("legend", False)
#
# ...

# %%
m1=sns.distplot(df.CriticRating)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20920\3430522549.py in ?()
# ----> 1 m1=sns.distplot(df.CriticRating)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'CriticRating'

# %%
sns.set_style('white')
